# %% [markdown]
# # markdown
#
# ## HTML - nadpis pomoci ##
# <h2> NADPIS pomoci H2 </h2>
#
# ## Obrazky
# ### Obrazek primym odkazem
#
#     Adresa, ktera je odsazena, funguje jen jako text.
#     <img src="data/1024px-Hubble_Interacting_Galaxy_AM_0500-620_(2008-04-24).jpg" />
#
# Adresa, ktera neni odsazena, funguje jako adresa.
#
# <img src="data/1024px-Hubble_Interacting_Galaxy_AM_0500-620_(2008-04-24).jpg" />
#
# ### Obrazek pomoci display function
# The display function is a general purpose tool for displaying different representations of objects. Think of it as print for these rich representations.

# %%
#obrazek pomoci kodu - funkce display
from IPython.display import display
from IPython.display import Image
i = Image(filename="data/1024px-Hubble_Interacting_Galaxy_AM_0500-620_(2008-04-24).jpg")
display(i)

# %%
#HTML pomoci funkce display
from IPython.display import HTML

s = """<table>
<tr>
<th>Header 1</th>
<th>Header 2</th>
</tr>
<tr>
<td>row 1, cell 1</td>
<td>row 1, cell 2</td>
</tr>
<tr>
<td>row 2, cell 1</td>
<td>row 2, cell 2</td>
</tr>
</table>"""

h = HTML(s)

display(h)
# Out:
# <table>
# <tr>
# <th>Header 1</th>
# <th>Header 2</th>
# </tr>
# <tr>
# <td>row 1, cell 1</td>
# <td>row 1, cell 2</td>
# </tr>
# <tr>
# <td>row 2, cell 1</td>
# <td>row 2, cell 2</td>
# </tr>
# </table>

# %% [raw]
# raw - kod nic nedela
# TOHLE JE PRO COMMIT A PUSH!!!
# b=20
# print(b)

# %%
#code
b=20
print(b)

# %%
#code
print("Aktualni adresar:")
# !pwd

files = !ls
print("Vypis souboru pomoci print:")
print(files)

print("Vypis souboru pomoci echo:")
# !echo $files
# Out:
# Aktualni adresar:
# /home/jovyan/demo
# Vypis souboru pomoci print:
# ['big.csv', 'data', 'jupyterlab.md', 'jupyterlab-slides.pdf', 'Lorenz.ipynb', 'lorenz.py', 'markdown_python.md', 'notebooks', 'notebooks_stampach.ipynb', 'TCGA_Data']
# Vypis souboru pomoci echo:
# [big.csv, data, jupyterlab.md, jupyterlab-slides.pdf, Lorenz.ipynb, lorenz.py, markdown_python.md, notebooks, notebooks_stampach.ipynb, TCGA_Data]

# %%
print("Diggy diggy hole!")
# Out:
# Diggy diggy hole!

# %%
#napoveda k funkci
print?
# Out:
# Docstring:
# print(value, ..., sep=' ', end='\n', file=sys.stdout, flush=False)
#
# Prints the values to a stream, or to sys.stdout by default.
# Optional keyword arguments:
# file:  a file-like object (stream); defaults to the current sys.stdout.
# sep:   string inserted between values, default a space.
# end:   string appended after the last value, default a newline.
# flush: whether to forcibly flush the stream.
# Type:      builtin_function_or_method

# %%
#napoveda k promenne
b?
# Out:
# Object `b` not found.

# %%
#vrati Input dane bunky
In[6]
# Out:
# '#obrazek pomoci kodu - proc to nefunguje\nfrom IPython.display import display\nfrom IPython.display import Image\ni = Image(filename="http://python.org/images/python-logo.gif")\ndisplay(i)'

# %%
#vrati Output dane bunky - proc to nefunguje?
Out[6]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-19-94c570e0cab9> in <module>
#       1 #vrati Output dane bunky - proc to nefunguje?
# ----> 2 Out[6]
#
# KeyError: 6
